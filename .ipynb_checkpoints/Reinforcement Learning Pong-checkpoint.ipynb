# %%
#Importing the necessary packages
import gym 
import tensorflow as tf 
import numpy as np 
import random 
import matplotlib.pyplot as plt
# Out:
# /Users/arjunsrivatsa/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#quick exploration of our environment
env = gym.make('Pong-v0')
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(6)
# Box(210, 160, 3)

# %%
class ExperienceBuffer: 
    
    def __init__(self): 
        self.buffer = []
        self.buffer_capacity = 1000000
        self.current_length = 0
    def write(self, obs): 
        if self.current_length == self.buffer_capacity: 
            self.buffer.pop()
            self.current_length -= 1
        self.buffer.append(obs)
        self.current_length +=1
    def sample_buffer(self, batch_to_sample): 
        return random.sample(self.buffer, min(batch_to_sample, self.current_length))
    def get_capacity(self): 
        return self.current_length

# %%
class Network:
    
    def __init__(self, session , n_out):
        self.session = session
        self.n_out = n_out
        # data placeholders
        self.x = tf.placeholder(tf.float32, [None, 4, 84, 84])
        self.y = tf.placeholder(tf.float32, [None, n_out], name='y')
        self.conv_1 = tf.layers.conv2d(self.x, filters = 32, kernel_size = [8,8], strides = 4, activation = tf.nn.relu)
        self.conv_2 = tf.layers.conv2d(self.conv_1, filters = 64, kernel_size = [4,4], strides = 2, activation = tf.nn.relu)
        #self.max_pool_1 = tf.layers.MaxPooling2D(pool_size = 2, strides = 2)
        self.flat_layer = tf.layers.flatten(self.conv_2)
        self.bottleneck_layer = tf.layers.dense(self.flat_layer, 512)
        self.q = tf.layers.dense(self.bottleneck_layer, n_out)
        #COULD BE BUGGY!
        self.loss = tf.reduce_sum(tf.square(self.y - self.q))
        self.train_step = tf.train.AdamOptimizer(1e-4).minimize(self.loss)
    def compute(self, input_frames):
        # evaluate the network and return the action values [q(s,a=0),q(s,a=1)]
        return self.session.run(self.q, feed_dict={self.x:input_frames})
    def train(self, x_batch, y_batch): 
            _ = self.session.run(self.train_step, feed_dict={self.x: x_batch, self.y: y_batch})

# %%
class ReshapeImage: 
    #Source for data processing: this is also the same as the openAI baseline https://github.com/fg91/Deep-Q-Learning/blob/master/DQN.ipynb
    def __init__(self, target_height = 84, target_width = 84):
        self.target_height = target_height
        self.target_width = target_width
        self.input_rgb_image = tf.placeholder(shape = [4,210,160,3], dtype = tf.uint8)
        self.grayscale_img = tf.image.rgb_to_grayscale(self.input_rgb_image)
        self.bounded_img = tf.image.crop_to_bounding_box(self.grayscale_img, 34, 0, 160, 160)
        self.final_processed = tf.image.resize_images(self.bounded_img, 
                                                [self.target_height, self.target_width], 
                                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    def return_processed_img(self, session, input_img):
        return session.run(self.final_processed, feed_dict = {self.input_rgb_image: input_img})

# %%
class Agent: 
    
    def __init__(self, session, policy): 
        #Want a pretty high gamma at first
        self.gamma = 0.99
        #Want pure exploration at first 
        self.epsilon = 1.0
        #want massive adjustments to Q function at first
        self.alpha = 1.0
        #There are six possible outputs
        self.n_out = 6
        #Tune this
        self.batch_size = 32
        self.total_reward = 0
        self.policy = policy
        self.session = session
        self.experience_buffer = ExperienceBuffer()
        self.q = Network(session, self.n_out)
        self.image_reshaper = ReshapeImage()
    def get_action(self, observation): 
        if self.policy == 'DQN':
            if np.random.randn() > self.epsilon: 
                #reshaped_obs = self.image_reshaper.return_processed_img(self.session, observation)
                #need to fix this to feed in 4 stacked frames
               # pos = np.argmax(self.q.compute(reshaped_obs), axis = 1)
                #return pos[0];
                print('use dqn')
                processed_obv = self.image_reshaper.return_processed_img(self.session, observation)
                padded_processed = np.expand_dims(processed_obv, axis = 0)
                action_values = self.q.compute(padded_processed)
                max_action = np.argmax(action_values, axis = 1)
                return max_action[0]
            else: 
                print('chose randomly')
                return random.randint(0,5)
        if self.policy == "dqn_test": 
                print('use blt in q function')
                processed_obv = self.image_reshaper.return_processed_img(self.session, observation)
                padded_processed = np.expand_dims(processed_obv, axis = 0)
                action_values = self.q.compute(padded_processed)
                max_action = np.argmax(action_values, axis = 1)
                return max_action[0]
    def adjust_epsilon(self, episode_number):
        self.epsilon = 0.01 + (1.0 - 0.01)*np.exp(-.001*episode_number)
    def update_q(): 
        self.batch_to_train_upon = self.experience_buffer.sample_buffer(self.batch_size);
    def gather_buffer_exp(self, last_obs, action, reward, obs): 
        processed_obv = self.image_reshaper.return_processed_img(self.session, obs)
        processed_obv = np.squeeze(processed_obv)
        processed_last_obv = self.image_reshaper.return_processed_img(self.session, last_obs)
        processed_last_obv = np.squeeze(processed_last_obv)
        self.experience_buffer.write((processed_last_obv, action, reward, processed_obv))
    def gather_reward(self, reward): 
        self.total_reward += reward
    def get_total_reward(self): 
        return self.total_reward
    def set_reward(self, new_reward): 
        self.total_reward = new_reward
    def return_buffer_size(self): 
        return self.experience_buffer.get_capacity()
    def update_q(self): 
        #PRETTY SURE THIS IS BUSTED BUT FIX LATER!
        self.sars_buffer = self.experience_buffer.sample_buffer(self.batch_size)
        the_x_batch = np.zeros(shape = (np.shape(self.sars_buffer)[0], 4,84,84))
        the_y_batch = np.zeros(shape = (np.shape(self.sars_buffer)[0], self.n_out))
        last_stateq = np.zeros(shape = (np.shape(self.sars_buffer)[0], self.n_out))
        next_q = np.zeros(shape = (np.shape(self.sars_buffer)[0], self.n_out))
        for i in range(np.shape(self.sars_buffer)[0]):
            padded_processed = np.expand_dims(self.sars_buffer[i][0], axis = 0)
            p2 = np.expand_dims(self.sars_buffer[i][3], axis = 0)
            last_stateq[i, :] = self.q.compute(padded_processed)
            next_q[i,:] = self.q.compute(p2)
        for i in range(np.shape(self.sars_buffer)[0]): 
            the_x_batch[i, :] = self.sars_buffer[i][0]
            for j in range(6): 
                if j == self.sars_buffer[i][1]:
                     #action we need to update
                    the_y_batch[i, j] = self.sars_buffer[i][2] + self.gamma * np.max(next_q[i])
                else: 
                     #use the previous q value
                    the_y_batch[i,j] = last_stateq[i,j]
                    
        self.q.train(the_x_batch, the_y_batch)

# %%
#Code to test the actual env:
with tf.Graph().as_default():
    with tf.Session() as session: 
        agent = Agent(session, 'DQN')
        session.run(tf.global_variables_initializer())
        episode_rewards = []
        newshape = ReshapeImage()
        for i_episode in range(200):
            print('starting episodes')
            observation = env.reset()
            observation = np.stack([observation,observation,observation,observation], axis = 0)
            print(np.shape(observation))
            agent.set_reward(0)
            for t in range(4000):
                flag = True
                #env.render()
                #action = agent.get_action(observation)
                new_observation, reward, done, info = env.step(0)
                new_matrix = np.zeros((4,210,160,3))
                new_matrix[0,:,:,:] = observation[1,:,:,:]
                new_matrix[1,:,:,:] = observation[2,:,:,:]
                new_matrix[2,:,:,:] = observation[3,:,:,:]
                new_matrix[3,:,:,:] = new_observation
                new_observation = new_matrix
                #checkout how the image looks
                new_img = newshape.return_processed_img(session,new_observation[:,:,:,:])
                print(np.shape(new_img))
                new_img = np.squeeze(new_img)
                print(np.shape(new_img))
                plt.imshow(new_img[3,:,:])
                plt.show()
                print(np.shape(new_observation))
                
                if done: 
                    new_observation = None
                    flag = False
                print("the reward at stage {} was {} and the action was {}".format(t, reward, action))
                agent.gather_reward(reward)
                if flag: 
                    agent.gather_buffer_exp(observation, action, reward, new_observation)
                #agent.update_q()
                observation = new_observation
                if done:
                    the_ep_reward = agent.get_total_reward()
                    print("Episode {} finished after {} timesteps with total reward {}".format(i_episode, t+1, agent.get_total_reward()))
                    episode_rewards.append(the_ep_reward)
                    print("current buffer size is {}".format(agent.return_buffer_size()))
                    break
            agent.adjust_epsilon(i_episode)
plt.plot(episode_rewards)
plt.show()
# Out:
# starting episodes
# (4, 210, 160, 3)
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 0 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 1 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 2 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 3 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 4 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 5 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 6 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 7 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 8 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 9 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 10 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 11 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 12 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 13 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 14 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 15 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 16 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 17 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 18 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 19 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 20 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 21 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 22 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 23 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 24 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 25 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 26 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 27 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 28 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 29 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 30 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 31 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 32 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 33 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 34 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 35 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 36 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 37 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 38 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 39 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 40 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 41 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 42 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 43 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 44 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 45 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 46 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 47 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 48 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 49 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 50 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 51 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 52 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 53 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 54 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 55 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 56 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 57 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 58 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 59 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 60 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 61 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 62 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 63 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 64 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 65 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 66 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 67 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 68 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 69 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 70 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 71 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 72 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 73 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 74 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 75 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 76 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 77 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 78 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 79 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 80 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 81 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 82 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 83 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 84 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 85 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 86 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 87 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 88 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 89 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 90 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 91 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 92 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 93 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 94 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 95 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 96 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 97 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 98 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 99 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 100 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 101 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 102 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 103 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 104 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 105 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 106 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 107 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 108 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 109 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 110 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 111 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 112 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 113 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 114 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 115 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 116 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 117 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 118 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 119 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 120 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 121 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 122 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 123 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 124 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 125 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 126 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 127 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 128 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 129 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 130 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 131 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 132 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 133 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 134 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 135 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 136 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 137 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 138 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 139 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 140 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 141 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 142 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 143 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 144 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 145 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 146 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 147 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 148 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 149 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 150 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 151 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 152 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 153 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 154 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 155 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 156 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 157 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 158 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 159 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 160 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 161 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 162 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 163 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 164 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 165 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 166 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 167 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 168 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 169 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 170 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 171 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 172 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 173 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 174 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 175 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 176 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 177 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 178 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 179 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 180 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 181 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 182 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 183 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 184 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 185 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 186 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 187 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 188 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 189 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 190 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 191 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 192 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 193 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 194 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 195 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 196 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 197 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 198 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 199 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 200 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 201 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 202 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 203 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 204 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 205 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 206 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 207 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 208 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 209 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 210 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 211 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 212 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 213 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 214 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 215 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 216 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 217 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 218 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 219 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 220 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 221 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 222 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 223 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 224 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 225 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 226 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 227 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 228 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 229 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 230 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 231 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 232 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 233 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 234 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 235 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 236 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 237 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 238 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 239 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 240 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 241 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 242 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 243 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 244 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 245 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 246 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 247 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 248 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 249 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 250 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 251 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 252 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 253 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 254 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 255 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 256 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 257 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 258 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 259 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 260 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 261 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 262 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 263 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 264 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 265 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 266 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 267 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 268 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 269 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 270 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 271 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 272 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 273 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 274 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 275 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 276 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 277 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 278 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 279 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 280 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 281 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 282 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 283 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 284 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 285 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 286 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 287 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 288 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 289 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 290 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 291 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 292 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 293 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 294 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 295 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 296 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 297 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 298 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 299 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 300 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 301 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 302 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 303 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 304 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 305 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 306 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 307 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 308 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 309 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 310 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 311 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 312 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 313 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 314 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 315 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 316 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 317 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 318 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 319 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 320 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 321 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 322 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 323 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 324 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 325 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 326 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 327 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 328 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 329 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 330 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 331 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 332 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 333 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 334 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 335 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 336 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 337 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 338 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 339 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 340 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 341 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 342 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 343 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 344 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 345 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 346 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 347 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 348 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 349 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 350 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 351 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 352 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 353 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 354 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 355 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 356 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 357 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 358 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 359 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 360 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 361 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 362 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 363 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 364 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 365 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 366 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 367 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 368 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 369 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 370 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 371 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 372 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 373 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 374 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 375 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 376 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 377 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 378 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 379 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 380 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 381 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 382 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 383 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 384 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 385 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 386 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 387 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 388 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 389 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 390 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 391 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 392 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 393 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 394 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 395 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 396 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 397 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 398 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 399 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 400 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 401 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 402 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 403 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 404 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 405 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 406 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 407 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 408 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 409 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 410 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 411 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 412 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 413 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 414 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 415 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 416 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 417 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 418 was -1.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 419 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 420 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 421 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 422 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 423 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# (4, 210, 160, 3)
# the reward at stage 424 was 0.0 and the action was 0
# (4, 84, 84, 1)
# (4, 84, 84)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-c6862de152d5> in <module>()
#      29                 print(np.shape(new_img))
#      30                 plt.imshow(new_img[3,:,:])
# ---> 31                 plt.show()
#      32                 print(np.shape(new_observation))
#      33
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     296             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297         else:
# --> 298             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299             if not format_dict:
#     300                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     511
#     512     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 513         FigureCanvasAgg.draw(self)
#     514         renderer = self.get_renderer()
#     515         original_dpi = renderer.dpi
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1188         renderer.open_group(__name__)
#    1189
# -> 1190         ticks_to_draw = self._update_ticks(renderer)
#    1191         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1192                                                                 renderer)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     969         Iterate through all of the major and minor ticks.
#     970         """
# --> 971         majorLocs = self.major.locator()
#     972         majorTicks = self.get_major_ticks(len(majorLocs))
#     973         self.major.formatter.set_locs(majorLocs)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in __call__(self)
#    1943     def __call__(self):
#    1944         vmin, vmax = self.axis.get_view_interval()
# -> 1945         return self.tick_values(vmin, vmax)
#    1946
#    1947     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1951         vmin, vmax = mtransforms.nonsingular(
#    1952             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1953         locs = self._raw_ticks(vmin, vmax)
#    1954
#    1955         prune = self._prune
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1934
#    1935             low = np.round(Base(step).le(_vmin - best_vmin) / step)
# -> 1936             high = np.round(Base(step).ge(_vmax - best_vmin) / step)
#    1937             ticks = np.arange(low, high + 1) * step + best_vmin + offset
#    1938             nticks = ((ticks <= vmax) & (ticks >= vmin)).sum()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/ticker.py in __init__(self, base)
#    1686     'this solution has some hacks to deal with floating point inaccuracies'
#    1687     def __init__(self, base):
# -> 1688         if base <= 0:
#    1689             raise ValueError("'base' must be positive")
#    1690         self._base = base
#
# KeyboardInterrupt:

# %%
plt.plot(episode_rewards)
plt.show()

# %%
#To test the image reshaper
with tf.Graph().as_default():
    with tf.Session() as sess: 
        reshaper = ReshapeImage()
        x = np.random.rand(4,210,160,3)
        fin_img = reshaper.return_processed_img(sess, x)
        print(fin_img.shape)
# Out:
# (4, 84, 84, 1)

# %%
#to test network 
with tf.Graph().as_default(): 
    with tf.Session() as session:
        x = np.random.rand(84,84,1)
        x = np.expand_dims(x, axis = 0)
        the_net = Network(session, 6)
        session.run(tf.global_variables_initializer())
        q_func = the_net.compute(x)
        print(q_func.shape)
        
       # y =np.array([ x[:,:,:,2]+x[:,:, :, 3]**2, x[:,:,:, 1]+x[:,:, :, 0]**3, x[:,:,:,2]+x[:,:, :, 3]**2,  x[:,:,:,2]+x[:,:, :, 3]**2,  x[:,:,:,2]+x[:,:, :, 3]**2,  x[:,:,:,2]+x[:,:, :, 3]**2 ])
            
       # print('MSE at iteration 0 is {}'.format(((the_net.compute(x) - y)**2).mean()))
        
        # now train...
       # for i in range(10000):
       #     f.train(x,y)
        
       # print('MSE at iteration 10000 is {}'.format(((f.compute(x) - y)**2).mean()))
# Out:
# (1, 6)

# %%
#Test to make sure the qn pick was working
with tf.Graph().as_default(): 
    with tf.Session() as sesh: 
        agent = Agent(sesh)
        sesh.run(tf.global_variables_initializer())
        obs = np.random.rand(210,160,3)
        xD = agent.get_action(obs)
        print(xD)
# Out:
# chose randomly
# 2

# %%
lol = ExperienceBuffer()
for i in range(300): 
    x = np.random.rand(84,84,4)
    y = np.random.randn()
    z = np.random.randn()
    w = np.random.rand(84,84,4)
    lol.write((x,y,z,w))
zed= lol.sample_buffer(32)
print(np.shape(zed))
print(np.shape(zed[0][0]))
# Out:
# (32, 4)
# (84, 84, 4)
